# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv("/Country Quater Wise Visitors - Copy.csv",encoding="ISO-8859-1")

# %%
df.head()
# Out:
#      Country of Nationality  2014 1st quarter (Jan-March)  \
# 0                    Canada                          33.1
# 1  United States Of America                          25.7
# 2                 Argentina                          46.8
# 3                    Brazil                          31.0
# 4                    Mexico                          23.6
#
#    2014 2nd quarter (Apr-June)  2014 3rd quarter (July-Sep)  \
# 0                         14.5                         15.7
# 1                         22.0                         20.6
# 2                         15.6                         13.9
# 3                         18.8                         18.7
# 4                         20.3                         26.5
#
#    2014 4th quarter (Oct-Dec))  2015 1st quarter (Jan-March)   \
# 0                         36.7                           34.2
# 1                         31.7                           26.4
# ...

# %%
df1 = pd.read_csv("/Country Wise Age Group - Copy.csv",encoding="ISO-8859-1")

# %%
df.head()
# Out:
#      Country of Nationality  2014 1st quarter (Jan-March)  \
# 0                    Canada                          33.1
# 1  United States Of America                          25.7
# 2                 Argentina                          46.8
# 3                    Brazil                          31.0
# 4                    Mexico                          23.6
#
#    2014 2nd quarter (Apr-June)  2014 3rd quarter (July-Sep)  \
# 0                         14.5                         15.7
# 1                         22.0                         20.6
# 2                         15.6                         13.9
# 3                         18.8                         18.7
# 4                         20.3                         26.5
#
#    2014 4th quarter (Oct-Dec))  2015 1st quarter (Jan-March)   \
# 0                         36.7                           34.2
# 1                         31.7                           26.4
# ...

# %%
df1 = pd.read_csv("/Country Wise Gender.csv",encoding="ISO-8859-1")

# %%
df.head()
# Out:
#      Country of Nationality  2014 1st quarter (Jan-March)  \
# 0                    Canada                          33.1
# 1  United States Of America                          25.7
# 2                 Argentina                          46.8
# 3                    Brazil                          31.0
# 4                    Mexico                          23.6
#
#    2014 2nd quarter (Apr-June)  2014 3rd quarter (July-Sep)  \
# 0                         14.5                         15.7
# 1                         22.0                         20.6
# 2                         15.6                         13.9
# 3                         18.8                         18.7
# 4                         20.3                         26.5
#
#    2014 4th quarter (Oct-Dec))  2015 1st quarter (Jan-March)   \
# 0                         36.7                           34.2
# 1                         31.7                           26.4
# ...

# %%
df1 = pd.read_csv("/General Data 2014-2020.csv",encoding="ISO-8859-1")

# %%
df.head()
# Out:
#      Country of Nationality  2014 1st quarter (Jan-March)  \
# 0                    Canada                          33.1
# 1  United States Of America                          25.7
# 2                 Argentina                          46.8
# 3                    Brazil                          31.0
# 4                    Mexico                          23.6
#
#    2014 2nd quarter (Apr-June)  2014 3rd quarter (July-Sep)  \
# 0                         14.5                         15.7
# 1                         22.0                         20.6
# 2                         15.6                         13.9
# 3                         18.8                         18.7
# 4                         20.3                         26.5
#
#    2014 4th quarter (Oct-Dec))  2015 1st quarter (Jan-March)   \
# 0                         36.7                           34.2
# 1                         31.7                           26.4
# ...
